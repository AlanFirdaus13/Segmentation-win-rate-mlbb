# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
td_MLBB = pd.read_csv('../Datasheet/mlbb_heros.csv')
print(td_MLBB)
# Out:
#      hero_name      role  defense_overall  offense_overall  \
# 0      Terizla   fighter              7.0              8.0
# 1       Martis   fighter              6.0              8.0
# 2        Grock      tank              8.0              5.0
# 3     Carmilla   support              5.0              5.0
# 4      Irithel  marksman              5.0              5.0
# ..         ...       ...              ...              ...
# 98   Esmeralda      mage              7.0              6.0
# 99   Benedetta  assassin              5.0              6.0
# 100      Brody  marksman              6.0              9.0
# 101    Natalia  assassin              6.0              9.0
# 102   Silvanna   fighter              6.0              6.0
#
#      skill_effect_overall  difficulty_overall  movement_spd  magic_defense  \
# 0                     6.0                 6.0           255             10
# 1                     5.0                 5.0           260             10
# ...

# %%
print(td_MLBB.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   hero_name             103 non-null    object
#  1   role                  103 non-null    object
#  2   defense_overall       103 non-null    float64
#  3   offense_overall       103 non-null    float64
#  4   skill_effect_overall  103 non-null    float64
#  5   difficulty_overall    103 non-null    float64
#  6   movement_spd          103 non-null    int64
#  7   magic_defense         103 non-null    int64
#  8   mana                  103 non-null    int64
#  9   hp_regen              103 non-null    int64
#  10  physical_atk          103 non-null    int64
#  11  physical_defense      103 non-null    int64
#  12  hp                    103 non-null    int64
#  13  attack_speed          103 non-null    float64
#  14  mana_regen            103 non-null    float64
# ...

# %%
td_MLBB.keys()
# Out:
# Index(['hero_name', 'role', 'defense_overall', 'offense_overall',
#        'skill_effect_overall', 'difficulty_overall', 'movement_spd',
#        'magic_defense', 'mana', 'hp_regen', 'physical_atk', 'physical_defense',
#        'hp', 'attack_speed', 'mana_regen', 'win_rate', 'pick_rate', 'ban_rate',
#        'release_year'],
#       dtype='object')

# %%
print(td_MLBB.isnull().sum())
# Out:
# hero_name               0
# role                    0
# defense_overall         0
# offense_overall         0
# skill_effect_overall    0
# difficulty_overall      0
# movement_spd            0
# magic_defense           0
# mana                    0
# hp_regen                0
# physical_atk            0
# physical_defense        0
# hp                      0
# attack_speed            0
# mana_regen              0
# win_rate                0
# pick_rate               0
# ban_rate                0
# release_year            0
# dtype: int64

# %%
print("jumlah baris pada datasheet : ", td_MLBB.shape[0])
print("jumlah kolom pada datasheet : ", td_MLBB.shape[1])
# Out:
# jumlah baris pada datasheet :  103
# jumlah kolom pada datasheet :  19

# %%
td_MLBB.describe().T
# Out:
#                       count         mean         std      min      25%  \
# defense_overall       103.0     5.786408    1.672444     2.00     4.50
# offense_overall       103.0     6.378641    1.771875     4.00     5.00
# skill_effect_overall  103.0     6.456311    1.538886     4.00     5.00
# difficulty_overall    103.0     5.922330    1.649060     3.00     5.00
# movement_spd          103.0   251.048544    9.261324   230.00   240.00
# magic_defense         103.0     9.611650    1.941462     0.00    10.00
# mana                  103.0   358.844660  217.446805     0.00   385.00
# hp_regen              103.0    37.961165    7.818934    19.00    34.00
# physical_atk          103.0   117.504854    8.451562    97.00   112.00
# physical_defense      103.0    19.135922    3.865505     2.00    17.00
# hp                    103.0  2585.932039  227.274528  1138.00  2500.50
# attack_speed          103.0     0.836505    0.046415     0.73     0.80
# ...

# %%
td_MLBB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   hero_name             103 non-null    object
#  1   role                  103 non-null    object
#  2   defense_overall       103 non-null    float64
#  3   offense_overall       103 non-null    float64
#  4   skill_effect_overall  103 non-null    float64
#  5   difficulty_overall    103 non-null    float64
#  6   movement_spd          103 non-null    int64
#  7   magic_defense         103 non-null    int64
#  8   mana                  103 non-null    int64
#  9   hp_regen              103 non-null    int64
#  10  physical_atk          103 non-null    int64
#  11  physical_defense      103 non-null    int64
#  12  hp                    103 non-null    int64
#  13  attack_speed          103 non-null    float64
#  14  mana_regen            103 non-null    float64
# ...

# %%
td_MLBB.role.value_counts().nlargest(40).plot(kind='bar', figsize=(10, 5))
plt.title("Number of role by mobile legends")
plt.ylabel("Number of Role")
plt.xlabel("Hero Role")
# Out:
# Text(0.5, 0, 'Hero Role')

# %%
td_MLBB.hero_name.value_counts().nlargest(40).plot(kind='bar', figsize=(10, 5))
plt.title("Number of role by mobile legends")
plt.ylabel("Number of Role")
plt.xlabel("Hero Role")
# Out:
# Text(0.5, 0, 'Hero Role')

# %%
plt.figure(figsize=(15, 15))
data = td_MLBB.corr()
sns.heatmap(data, cmap="YlGnBu", annot=True)
data.T
# Out:
#                       defense_overall  offense_overall  skill_effect_overall  \
# defense_overall              1.000000        -0.180869             -0.190316
# offense_overall             -0.180869         1.000000             -0.621290
# skill_effect_overall        -0.190316        -0.621290              1.000000
# difficulty_overall          -0.194477         0.191349              0.172498
# movement_spd                 0.486788         0.118357             -0.405362
# magic_defense               -0.086185        -0.042334              0.158337
# mana                        -0.147528        -0.415145              0.452138
# hp_regen                     0.497925        -0.164519             -0.132953
# physical_atk                 0.154748         0.286299             -0.319406
# physical_defense             0.524694        -0.112080             -0.205006
# hp                           0.362040        -0.001786             -0.263965
# ...

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'win_rate', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='win_rate'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'ban_rate', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='ban_rate'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'pick_rate', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='pick_rate'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'attack_speed', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='attack_speed'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'mana_regen', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='mana_regen'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y = 'defense_overall', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='defense_overall'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y = 'offense_overall', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='offense_overall'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'skill_effect_overall', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='skill_effect_overall'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'difficulty_overall', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='difficulty_overall'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'movement_spd', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='movement_spd'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'magic_defense', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='magic_defense'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'mana', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='mana'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'hp_regen', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='hp_regen'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'physical_atk', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='physical_atk'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'physical_defense', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='physical_defense'>

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'hp', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='hp'>

# %%
td_MLBB.head()
# Out:
#   hero_name      role  defense_overall  offense_overall  skill_effect_overall  \
# 0   Terizla   fighter              7.0              8.0                   6.0
# 1    Martis   fighter              6.0              8.0                   5.0
# 2     Grock      tank              8.0              5.0                   6.0
# 3  Carmilla   support              5.0              5.0                   9.0
# 4   Irithel  marksman              5.0              5.0                   8.0
#
#    difficulty_overall  movement_spd  magic_defense  mana  hp_regen  \
# 0                 6.0           255             10   430        54
# 1                 5.0           260             10     0        35
# 2                 4.0           260             10   430        42
# 3                 5.0           255             10   430        39
# 4                 7.0           260             10   438        35
#
#    physical_atk  physical_defense    hp  attack_speed  mana_regen  win_rate  \
# ...

# %%
plt.figure(figsize=(6,4))
sns.barplot(x = 'role', y= 'release_year', data = td_MLBB)
# Out:
# <AxesSubplot:xlabel='role', ylabel='release_year'>
